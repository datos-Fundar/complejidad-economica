# %%
import pandas as pd
import csv
import math

def csvToArrayOfDictionaries(csv):
  result = []
  for x in csv:
    countRow = 0;
    for y in csv[x]:
      if(len(result) < (countRow+1)): 
        result.append({})

      result[countRow][x] = y
      countRow+=1

  return result

servicios = csvToArrayOfDictionaries(pd.read_csv('/content/servicios_ambientales_sin_procesar.csv'))

def getService(service):
    if(isinstance(service["WTO_Environmental_Benefit_Description"], str)):
      return service["WTO_Environmental_Benefit_Description"]

    if(isinstance(service["APEC_Environmental_Benefit_Description"], str)):
      return service["APEC_Environmental_Benefit_Description"]

    return getServiceOnOtherColumns(service)

def getServiceOnOtherColumns(service):
    finalString = ''
    keys = service.keys()

    for key in keys:
      remove_keys = [
        "OECD_List_Iidentifier",
        "OECD_C: Resources management group",
        "OECD_List_Iidentifier",
        "Product_id",
        "WTO_2011_id",
        "WTO_Reference_Universe_List",
        "WTO_Others",
        "OECD_A: Pollution Management",
        "OECD2_List_identifier",
        "OECD_B: Cleaner Technologies and products",
        "OECD2_List_identifier",
        "APEC_List_Identifier",
        "WTO_Switzerland",
        "WTO_Sample_Core_List"
      ]
      if(key in remove_keys): continue

      if(service[key] == 1):
        finalString += key + ', '

    return finalString.strip(', ')

def getTranslation(service):
  translations = {
     "OECD_C2: Water supply": "Suministro de agua", 
     "OECD_C4: Renewable energy plant": "Plantas de energías renovables",
     "Carbon Capture and Storage, Efficient consumption of energy technologies, Gas flaring emission reduction technologies": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía, tecnologías de reducción de emisiones de quema de gas",
     "Carbon capture and storage technologies (CCS), Efficient consumption of energy technologies (EC)": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía",
     "Carbon Capture and Storage, Efficient Consumption of Energy Technologies": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía",
     "Carbon Capture and Storage, Efficient consumption of energy technologies,  Gas flaring emission reduction technologies": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía, tecnologías de reducción de emisiones de quema de gas",
     "OECD_A2 Wastewater management": "Manejo de aguas residuales",
     "OECD_B2: Cleaner/resource efficient products": "Productos más limpios y eficientes en el uso de recursos",
     "Renewable Energy, Renewable Products and Energy Source": "Energía renovable, productos renovables y fuentes de energía",
     "WTO_2_Environmnetally Preferable Products based on End-Use or Disposal Characteristics": "Productos ambientalmente preferibles según las características de uso final o eliminación (cuando pasa a ser residuo)",
     "OECD_A1 Air pollution control, OECD_A2 Wastewater management": "Control de la contaminación del aire, Manejo de aguas residuales",
     "OECD_A2 Wastewater management, OECD_C2: Water supply": "Manejo de aguas residuales, Suministro de agua",
     "OECD_A3 Solid waste management": "Manejo de residuos sólidos",
     "OECD2: Heat and energy managemetn": "Gestión del calor y la energía",
     "OECD2: Renewable Energy Plant": "Plantas de energías renovables",
     "OECD2: Management of solid and hazardous waste and recycling systems": "Gestión y reciclado de residuos peligrosos",
     "Assists in the reduction of noise levels in buildings.": "Reduce el nivel de ruido en edificios",
     "These mats help save energy and reduce noise levels in buildings.": "Ahorran energía y reducen el nivel de ruido en edificios",
     "Use for soil erosion as a soil cover, biodegradable from waste.": "Se utiliza para la erosión del suelo como cobertura del suelo, biodegradable a partir de residuos",
     "OECD2: Environmentally preferable products": "Productos ambientalmente preferibles según las características de uso final o eliminación (cuando pasa a ser residuo)",
     "Compared with the conventional fluorescent or incandescent lamps, it is long life, low power consumption, energy saving and no toxic substance (mercury free).": "En comparación con las lámparas fluorescentes o incandescentes convencionales, es de larga duración, bajo consumo de energía, ahorro de energía y sin sustancias tóxicas (sin mercurio).",
     "Compared with the conventional fluorescent or incandescent lamps, it is long life, low power consumption,  energy saving and no toxic substance (mercury free).": "En comparación con las lámparas fluorescentes o incandescentes convencionales, es de larga duración, bajo consumo de energía, ahorro de energía y sin sustancias tóxicas (sin mercurio).",
     "Used to line landfills to prevent leachate (water run-off) from contaminating groundwater resources. Also used to cover landfills and prevent methane from escaping into atmosphere. These membrane systems are also used for the reinforcement and protection of soil, including under oil refineries, gas stations etc.": "Se utiliza para revestir rellenos sanitarios para evitar que los lixiviados (escorrentías de agua) contaminen los recursos hídricos subterráneos. También se utiliza para cubrir vertederos y evitar que el metano se escape a la atmósfera. Estos sistemas de membranas también se utilizan para el refuerzo y protección del suelo, incluso debajo de refinerías de petróleo, estaciones de servicio, etc.",
     "Renewable bamboo-based products are substitutions of wooden necessities. Since bamboo is characterized by short growing cycle, these enviroment-friendly products can save a great deal of water,soil and air resources.": "Los productos renovables a base de bambú son sustituciones de las necesidades de madera. Dado que el bambú se caracteriza por un ciclo de cultivo corto, estos productos respetuosos con el medio ambiente pueden ahorrar una gran cantidad de recursos de agua, suelo y aire.",
     "The natural fiber composition differentiates jute from alternative synthetic materials due to its biodegradability and sustainable sources. Jute fibers are used for packaging and woven fabric.": "La composición de fibras naturales diferencia al yute de los materiales sintéticos alternativos debido a su biodegradabilidad y fuentes sostenibles. Las fibras de yute se utilizan para embalajes y tejidos.",
     "Used to ensure efficient leachate or gas landfill drainage.": "Se utiliza para garantizar un drenaje eficiente de los vertederos de lixiviados o gas.",
     "More biodegradable than synthetic fibre alternatives and made from a renewable resource.": "Más biodegradable que las alternativas de fibra sintética y elaborado a partir de un recurso renovable.",
     "Use of Turtle Excluder Devices (TEDs) reduces turtle mortality by 90-100 per cent.": "El uso de dispositivos de exclusión de tortugas (TEDs) reduce la mortalidad de tortugas en un 90-100 por ciento.",
     "OECD2: Natural Resources Protection": "Protección de los recursos naturales",
     "OECD_C5: Heat/energy savings and management": "Gestión del calor y la energía",
     "OECD_A2 Wastewater management, OECD2: Waste water management and potable water treatment": "Manejo de aguas residuales y potabilización del agua",
     "OECD2: Waste water management and potable water treatment": "Manejo de aguas residuales y potabilización del agua",
     "OECD_A1 Air pollution control, OECD_C5: Heat/energy savings and management": "Control de la contaminación del aire, Gestión del calor y la energía",
     "OECD2: Cleaner or more resource efficient technologies and products": "Productos más limpios y eficientes en el uso de recursos",
     "For handling and transport of wastewater or slurries during treatment.": "Para manipulación y transporte de aguas residuales o lodos durante el tratamiento",
     "Air handling equipment. Transport or extraction of polluted air, corrosive gases or dust.": "Equipo de manejo de aire. Transporte o extracción de aire contaminado, gases corrosivos o polvo",
     "Air handling equipment. Transport or extraction of polluted air, corrosive gases or dust. Transport or extraction of polluted air and corrosive gases or dust.": "Equipo de manejo de aire. Transporte o extracción de aire contaminado, gases corrosivos o polvo. Transporte o extracción de aire contaminado y gases o polvos corrosivos",
     "Low CO2 emission, using less electricity": "Baja emisión de CO2, utilizando menos electricidad",
     "Low CO2 emission, using less electricity Such systems transfer (\"pump\") the heat available in land and water masses to either heat or cool buildings.": "Baja emisión de CO2, utilizando menos electricidad Dichos sistemas transfieren (\"bombean\") el calor disponible en la tierra y las masas de agua para calentar o enfriar edificios",
     "WTO_1_Renewable_Energy, WTO_2_Renewable Products and Energy Source": "Energías renovables, productos renovables y fuentes de energía",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Noise and Vibration Abatement": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía, reducción de ruidos",
     "Low gas consumption, fuel economy, CO2 emission and pollutants such as NOx and SOx emission    ":"Bajo consumo de gas, economía de combustible, emisión de CO2 y contaminantes como la emisión de NOx y SOx",
     "WTO_1_Air_Pollution_Control, WTO_1_Renewable_Energy, WTO_2_Renewable Energy": "Control de la contaminación del aire, energías renovables",
     "Carbon Capture and Storage, Efficient consumption of energy technologies, These items facilitate the delivery of safe drinking water and sanitation.": "Captura y almacenamiento de carbono, consumo eficiente de tecnologías energéticas. Estos elementos facilitan la entrega de agua potable y saneamiento",
     "Waste Management and Water Treatment, WWM, Renewable Energy, Renewable Products and Energy Source": "Gestión de residuos y tratamiento de agua, energías renovables, productos renovables y fuentes de energía",
     "Renewable Energy, Renewable Products and Energy Source": "Energías renovables, productos renovables y fuentes de energía",
     "The natural fibre composition differentiates sisal from alternative synthetic materials due to its biodegradability and sustainable sources. Sisal fibres also used in recycled paper.": "La composición de fibras naturales diferencia al sisal de los materiales sintéticos alternativos debido a su biodegradabilidad y fuentes sostenibles. Las fibras de sisal también se utilizan en papel reciclado",
     "Waterless urinals and composting toilets minimise water use.  Composting toilets also provide self contained sewage treatment on site, with no need for sewers and treatment plants. These items also do not pollute ground or surface water or soil (unlike septic tanks or pit latrines) and produce safe, useful compost.": "Los urinarios sin agua y los inodoros de compostaje minimizan el uso de agua. Los inodoros de compostaje también proporcionan tratamiento de aguas residuales autónomo en el sitio, sin necesidad de alcantarillas ni plantas de tratamiento. Estos artículos tampoco contaminan el suelo o el agua superficial o el suelo (a diferencia de los tanques sépticos o las letrinas de pozo) y producen abono útil y seguro.",
     "Used to line landfills to prevent leachate (water run-off) from contaminating groundwater resources.  Also used to cover landfills and prevent methane from escaping into atmosphere. These membrane systems are also used for the reinforcement and protection of soil, including under oil refineries, gas stations etc.": "Se utiliza para revestir rellenos sanitarios para evitar que los lixiviados (escorrentías de agua) contaminen los recursos hídricos subterráneos. También se utiliza para cubrir vertederos y evitar que el metano se escape a la atmósfera. Estos sistemas de membranas también se utilizan para el refuerzo y protección del suelo, incluso debajo de refinerías de petróleo, estaciones de servicio, etc.",
     "These items facilitate the delivery of safe drinking water and sanitation.": "Estos elementos facilitan la entrega de agua potable y saneamiento",
     "These items facilitate the delivery of safe drinking water and sanitation ": "Estos elementos facilitan la entrega de agua potable y saneamiento",
     "These items facilitate the delivery of safe drinking water and sanitation, which are key MDG priorities ": "Estos elementos facilitan la entrega de agua potable y saneamiento",
     "Environmental Technologies, Carbon Capture and Storage, Efficient Consumption of Energy Technologies": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía",
     "Carbon, capture and storage, Efficient use of energy technologies, These items facilitate the delivery of safe drinking water and sanitation": "Captura y almacenamiento de carbono, consumo eficiente de tecnologías energéticas. Estos elementos facilitan la entrega de agua potable y saneamiento",
     "Industrial mufflers are used for reducing engine noise. ": "Los silenciadores industriales se utilizan para reducir el ruido de motores",
     "Industrial mufflers are used for reducing engine noiset. ": "Los silenciadores industriales se utilizan para reducir el ruido de motores",
     "Used to concentrate and intensify solar power in a solar energy system.": "Se utiliza para concentrar e intensificar la energía solar en un sistema de energía solar.",
     "WTO_1_Environmental Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente",
     "WTO_1_Environmental Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD2: Environmental monitoring, analysis and assessment equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente",
     "Air handling equipment. Transport or extraction of polluted air, corrosive gases or dust.  Transport or extraction of polluted air and corrosive gases or dust.": "Equipo de manejo de aire. Transporte o extracción de aire contaminado, gases corrosivos o polvo. Transporte o extracción de aire contaminado y gases o polvos corrosivos",
     "Gas turbines for electrical power generation from recovered landfill gas, coal mine vent gas, or biogas (clean energy system). Note that these turbines do \"not exceed 5,000 kW\".": "Turbinas de gas para la generación de energía eléctrica a partir de gas de vertedero recuperado, gas de ventilación de minas de carbón o biogás (sistemas de energía limpia)",
     "Gas turbines for electrical power generation from recovered landfill gas, coal mine vent gas, or biogas (clean energy system). Note that these turbines do \"exceed 5,000 kW\".": "Turbinas de gas para la generación de energía eléctrica a partir de gas de vertedero recuperado, gas de ventilación de minas de carbón o biogás (sistemas de energía limpia)",
     "For handling and transport of wastewater or slurries during treatment. ": "Para manipulación y transporte de aguas residuales o lodos durante el tratamiento",
     "Machines and appliances designed for a wide range of areas of environmental management including waste, waste water, drinking water production and soil remediation.  In-vessel composting systems can handle large amounts of waste and speed up decomposition. Trash compactors reduce the volume of solid waste, allowing more efficient transport and disposal. ": "Máquinas y aparatos diseñados para una amplia gama de áreas de gestión medioambiental que incluyen residuos, aguas residuales, producción de agua potable y remediación de suelos. Los sistemas de compostaje en recipientes pueden manejar grandes cantidades de desechos y acelerar la descomposición. Los compactadores de basura reducen el volumen de residuos sólidos, lo que permite un transporte y una eliminación más eficientes. ",
     "WTO_1_Renewable_Energy, WTO_2_Renewable Products and Energy Source, OECD2: Cleaner or more resource efficient technologies and products": "Productos más limpios y eficientes en el uso de recursos",
     "Compared with dry cell batteries, it can be recharged (can be reused) and reduce the waste. In case of automotive use, superior energy saving can be realized due to high efficiency. No CO2 emission": "En comparación con las baterías de celda seca, se puede recargar (se puede reutilizar) y reducir el desperdicio. En caso de uso automotriz, se puede lograr un ahorro de energía superior debido a la alta eficiencia. Sin emisión de CO2",
     "Used to elevate and support a wind turbine for the generation of renewable energy.": "Se utiliza para elevar y soportar una turbina eólica para la generación de energías renovables",
     "Containers of any material, of any form, for liquid or solid waste, including for municipal or dangerous waste. The containers can be of assistance in the conversion of waste to gas, which can be used to generate energy. ": "Contenedores de cualquier material, de cualquier forma, para desechos líquidos o sólidos, incluidos los desechos municipales o peligrosos",
     "For handling and storage of wastewater/sewage during treatment.  Containers of any material, of any form, for liquid or solid waste, including for municipal or dangerous waste. ": "Contenedores de cualquier material, de cualquier forma, para desechos líquidos o sólidos, incluidos los desechos municipales o peligrosos",
     "Containers of any material, of any form, for liquid or solid waste, including for municipal or dangerous waste.": "Contenedores de cualquier material, de cualquier forma, para desechos líquidos o sólidos, incluidos los desechos municipales o peligrosos",
     "Hydroelectric power generation produces no greenhouse gas emissions.  ": "La generación de energía hidroeléctrica no produce emisiones de gases de efecto invernadero",
     "Heliostats orient mirrors in concentrated solar power systems to reflect sunlight on to a CSP receiver. ": "Los heliostatos orientan los espejos en los sistemas de energía solar concentrada para reflejar la luz solar en un receptor",
     "These instruments include microtomes which are devices that prepare slices of samples for analysis. Also included here are parts of the instruments classified in 9027 and described above.": "Estos instrumentos incluyen microtomos que son dispositivos que preparan cortes de muestras para su análisis.",
     "Uses solar thermal energy to heat water, producing no pollution.  Use of solar water heating displaces the burning of other, pollution-creating fuels.": "Utiliza energía solar térmica para calentar el agua, sin producir contaminación. El uso de calentamiento solar de agua desplaza la quema de otros combustibles que generan contaminación",
     "Device used in waste water management, which requires sludge to be treated": "Para manipulación y transporte de aguas residuales o lodos durante el tratamiento",
     "Uses solar thermal energy for cooking, thereby producing no air pollution. The use of solar stoves is replacing heating with firewood or other non-renewable energy sources (e.g. oil, gas) and allows for preservation of firewood (especially important in arid areas) and is suitable for off-grid usage.": "Utiliza energía solar térmica para cocinar, por lo que no produce contaminación del aire. El uso de estufas solares está reemplazando la calefacción con leña u otras fuentes de energía no renovables (por ejemplo, petróleo, gas) y permite la conservación de la leña (especialmente importante en áreas áridas) y es adecuado para uso fuera de la red",
     "Boilers for the production of heat and power on the basis of (renewable) biomass fuels.": "Calderas para la producción de calor y energía a base de combustibles de biomasa (renovables)",
     "Parts for the biomass boilers described above.": "Partes para calderas",
     "Used for solid waste treatment or recycling.": "Utilizado para el tratamiento o reciclaje de residuos sólidos.",
     "Such systems transfer (\"pump\") the heat available in land and  water masses to either heat or cool buildings.": "Dichos sistemas transfieren (\"bombean\") el calor disponible en masas de tierra y agua para calentar o enfriar edificios.",
     "WTO_1_Environmental Technologies, WTO_2_Cleaner or More Resource Efficient Technologies and Products, OECD2: Cleaner or more resource efficient technologies and products": "Productos más limpios y eficientes en el uso de recursos",
     "WTO_2_Natural Resource Protection, OECD2: Natural Resources Protection": "Protección de los recursos naturales",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD2: Environmental monitoring, analysis and assessment equipment": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía, tecnologías de reducción de emisiones de quema de gas. Equipos de seguimiento, análisis y evaluación del medioambiente",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD_A6 Environmental monitoring, analysis and assessment , OECD2: Environmental monitoring, analysis and assessment equipment": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía, tecnologías de reducción de emisiones de quema de gas. Equipos de seguimiento, análisis y evaluación del medioambiente",
     "WTO_1_Renewable_Energy, WTO_2_Renewable Energy, OECD2: Renewable Energy Plant": "Plantas de energías renovables",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD_A6 Environmental monitoring, analysis and assessment , OECD2: Renewable Energy Plant": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía, tecnologías de reducción de emisiones de quema de gas. Equipos de seguimiento, análisis y evaluación del medioambiente. Plantas de energías renovables",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_2_Management of Solid and Hazardous Waste and Recycling Systems, OECD2: Management of solid and hazardous waste and recycling systems":  "Gestión y reciclado de residuos solidos y residuos peligrosos",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Management of Solid and Hazardous Waste and Recycling Systems, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, OECD_A1 Air pollution control, OECD_A2 Wastewater management, OECD_A3 Solid waste management, OECD2: Management of solid and hazardous waste and recycling systems": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía, tecnologías de reducción de emisiones de quema de gas. Gestión y reciclado de residuos",
     "WTO_1_Environmental Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD_A6 Environmental monitoring, analysis and assessment , OECD2: Environmental monitoring, analysis and assessment equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Natural Risk Management, OECD2: Environmental monitoring, analysis and assessment equipment": "Captura y almacenamiento de carbono, tecnologías de consumo eficiente de energía. Equipos de seguimiento, análisis y evaluación del medioambiente, Gestión de riesgos naturales",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Clean Up or Remediation of Soil and Water, WTO_2_Efficient Consumption of Energy Technologies, OECD_A2 Wastewater management, OECD2: Waste water management and potable water treatment": "Limpieza o remediación de suelo y agua. Manejo de aguas residuales y potabilización del agua",
     "WTO_1_Air_Pollution_Control, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, OECD2: Air pollution control": "Control de la contaminación del aire",
     "WTO_1_Environmental Technologies, WTO_2_Energy Efficiency": "Eficiencia energética",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Heat and Energy Management, OECD2: Heat and energy managemetn": "Gestión del calor y la energía",
     "WTO_1_Air_Pollution_Control, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, OECD_A1 Air pollution control, OECD2: Air pollution control": "Control de la contaminación del aire",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD_A6 Environmental monitoring, analysis and assessment , OECD_C5: Heat/energy savings and management, OECD2: Environmental monitoring, analysis and assessment equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente. Gestión del calor y la energía",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_2_Waste Water Management and Potable Water Treatment": "Manejo de aguas residuales y potabilización del agua",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Waste Water Management and Potable Water Treatment, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Resources and Pollution Management, OECD2: Waste water management and potable water treatment": "Manejo de aguas residuales y potabilización del agua",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_2_Waste Water Management and Potable Water Treatment, OECD2: Waste water management and potable water treatment": "Manejo de aguas residuales y potabilización del agua",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_2_Waste Water Management and Potable Water Treatment, OECD_A4 Remediation and cleanup, OECD2: Waste water management and potable water treatment": "Limpieza o remediación de suelo y agua. Manejo de aguas residuales y potabilización del agua",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Waste Water Management and Potable Water Treatment, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Resources and Pollution Management, OECD_A2 Wastewater management, OECD2: Waste water management and potable water treatment": "Manejo de aguas residuales y potabilización del agua",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD2: Environmental monitoring, analysis and assessment equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente.",
     "OECD_A5 Noise and vibration abatement": "Reducción de ruido y vibraciones",
     "OECD_C5: Heat/energy savings and management, OECD2: Heat and energy managemetn": "Gestión del calor y la energía",
     "OECD2: Environmental monitoring, analysis and assessment equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente",
     "OECD_A3 Solid waste management, OECD2: Clean up or remediation of soil and water": "Limpieza o remediación de suelo y agua",
     "WTO_1_Renewable_Energy, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Renewable Energy, OECD2: Renewable Energy Plant": "Plantas de energías renovables",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Management of Solid and Hazardous Waste and Recycling Systems, WTO_2_Waste Management, Recycling and Remediation, WTO_2_Efficient Consumption of Energy Technologies, OECD2: Air pollution control": "Manejo de Residuos Sólidos y Sistemas de Reciclaje",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD_A6 Environmental monitoring, analysis and assessment , OECD2: Environmental monitoring, analysis and assessment equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente.",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD_A6 Environmental monitoring, analysis and assessment": "Equipos de seguimiento, análisis y evaluación del medioambiente.",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, WTO_2_Noise and Vibration Abatement, OECD2: Noise and vibration abatement": "Equipos de seguimiento, análisis y evaluación del medioambiente. Reducción de ruido y vibraciones",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Heat and Energy Management, OECD_C5: Heat/energy savings and management, OECD2: Environmental monitoring, analysis and assessment equipment": "Gestión del calor y la energía",
     "WTO_1_Environmental Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD_A6 Environmental monitoring, analysis and assessment": "Equipos de seguimiento, análisis y evaluación del medioambiente.",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Heat and Energy Management, WTO_2_Resources and Pollution Management, OECD_C5: Heat/energy savings and management, OECD2: Environmental monitoring, analysis and assessment equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente. Gestión del calor y la energía",
     "WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD_A2 Wastewater management, OECD2: Environmental monitoring, analysis and assessment equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente. Manejo de aguas residuales",
     "WTO_1_Air_Pollution_Control, WTO_1_Environmental Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD_A2 Wastewater management, OECD2: Environmental monitoring, analysis and assessment equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente. Manejo de aguas residuales. Control de la contaminación del aire",
     "WTO_1_Environmental Technologies, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Environmental Monitoring, Analysis and Assessment Equipment, OECD2: Environmental monitoring, analysis and assessment equipment": "Equipos de seguimiento, análisis y evaluación del medioambiente",
     "WTO_1_Air_Pollution_Control, WTO_1_Renewable_Energy, WTO_2_Renewable Energy, OECD2: Clean up or remediation of soil and water": "Control de la contaminación del aire. Limpieza o remediación de suelo y agua",
     "WTO_1_Renewable_Energy, WTO_2_Renewable Energy, WTO_2_Renewable Products and Energy Source, OECD2: Renewable Energy Plant": "Plantas de energías renovables",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_2_Clean Up or Remediation of Soil and Water, OECD2: Clean up or remediation of soil and water": "Limpieza o remediación de suelo y agua",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_2_Management of Solid and Hazardous Waste and Recycling Systems, OECD_A1 Air pollution control, OECD_A2 Wastewater management, OECD_A3 Solid waste management, OECD2: Management of solid and hazardous waste and recycling systems":"Utilizado para el tratamiento o reciclaje de residuos sólidos",
     "WTO_1_Renewable_Energy, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Renewable Energy, WTO_2_Renewable Products and Energy Source, OECD2: Cleaner or more resource efficient technologies and products":"Productos más limpios y eficientes en el uso de recursos",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Management of Solid and Hazardous Waste and Recycling Systems, WTO_2_Efficient Consumption of Energy Technologies, OECD2: Management of solid and hazardous waste and recycling systems": "Utilizado para el tratamiento o reciclaje de residuos sólidos",
     "WTO_1_Renewable_Energy, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Renewable Energy, OECD_C4: Renewable energy plant, OECD2: Renewable Energy Plant": "Plantas de energías renovables",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Waste Water Management and Potable Water Treatment, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Resources and Pollution Management": "Manejo de aguas residuales y potabilización del agua",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_2_Management of Solid and Hazardous Waste and Recycling Systems, OECD_A3 Solid waste management, OECD2: Management of solid and hazardous waste and recycling systems": "Utilizado para el tratamiento o reciclaje de residuos sólidos",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_2_Waste Water Management and Potable Water Treatment, OECD2: Management of solid and hazardous waste and recycling systems": "Utilizado para el tratamiento o reciclaje de residuos sólidos",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Waste Water Management and Potable Water Treatment, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, OECD_A1 Air pollution control, OECD_A2 Wastewater management, OECD2: Waste water management and potable water treatment":"Manejo de aguas residuales. Control de la contaminación del aire",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Clean Up or Remediation of Soil and Water, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, OECD_A2 Wastewater management, OECD2: Clean up or remediation of soil and water":"Limpieza o remediación de suelo y agua",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Clean Up or Remediation of Soil and Water, WTO_2_Efficient Consumption of Energy Technologies, OECD_A2 Wastewater management, OECD2: Clean up or remediation of soil and water":"Limpieza o remediación de suelo y agua",
     "WTO_1_Renewable_Energy, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Renewable Energy, OECD_C5: Heat/energy savings and management, OECD2: Renewable Energy Plant":"Gestión del calor y la energía. Plantas de energías renovables",
     "WTO_1_Air_Pollution_Control, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Others, WTO_2_Renewable Energy, OECD_A1 Air pollution control, OECD2: Waste water management and potable water treatment": "Control de la contaminación del aire. Manejo de aguas residuales y potabilización del agua",
     "WTO_1_Renewable_Energy, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Heat and Energy Management, WTO_2_Renewable Energy, OECD_C5: Heat/energy savings and management, OECD2: Heat and energy managemetn": "Gestión del calor y la energía",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Waste Water Management and Potable Water Treatment, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, WTO_2_Others, OECD2: Management of solid and hazardous waste and recycling systems": "Utilizado para el tratamiento o reciclaje de residuos sólidos",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Management of Solid and Hazardous Waste and Recycling Systems, WTO_2_Gas Flairing Emission Reduction, WTO_2_Efficient Consumption of Energy Technologies, OECD_A3 Solid waste management, OECD2: Management of solid and hazardous waste and recycling systems":  "Utilizado para el tratamiento o reciclaje de residuos sólidos",
     "WTO_1_Air_Pollution_Control, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Efficient Consumption of Energy Technologies, OECD_A1 Air pollution control, OECD2: Air pollution control": "Control de la contaminación del aire",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Waste Water Management and Potable Water Treatment, WTO_2_Efficient Consumption of Energy Technologies, OECD_A2 Wastewater management, OECD2: Waste water management and potable water treatment": "Manejo de aguas residuales y potabilización del agua",
     "WTO_1_Air_Pollution_Control, WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Waste Water Management and Potable Water Treatment, WTO_2_Efficient Consumption of Energy Technologies, OECD2: Air pollution control": "Control de la contaminación del aire. Manejo de aguas residuales y potabilización del agua",
     "WTO_1_Waste_Management_and_Water_Treatment, WTO_1_Environmental Technologies, WTO_1_Carbon_Capture_and_Storage, WTO_2_Waste Water Management and Potable Water Treatment, WTO_2_Efficient Consumption of Energy Technologies, OECD2: Waste water management and potable water treatment": "Manejo de aguas residuales y potabilización del agua"
  }

  if(service in translations): 
    return translations[service]

  return ''



finalArray = []

for x in servicios: 
  service = getService(x)
  translation = getTranslation(service)
  if(translation == ''): 
    service = getServiceOnOtherColumns(x)
    translation = getTranslation(service)

  finalArray.append({"code":x["HS1992_6digit"], "service":translation})

keys = ["code", "service"]
with open('servicios.csv', 'w', newline='')  as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(finalArray)
